# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_outlier_treated.csv')

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat      experion windchants  sector 112   4.75         12623.0
# 1          flat               ild greens  sector 37c   0.90          5614.0
# 2          flat  signature global synera   sector 81   0.45          7525.0
# 3         house              independent   sector 43   9.85         29642.0
# 4          flat               sare homes   sector 92   0.80          4695.0
#
#      area                                       areaWithType  bedRoom  \
# 0  3763.0             Super Built up area 3763(349.59 sq.m.)        3
# 1  1603.0  Super Built up area 1603(148.92 sq.m.)Built Up...        3
# 2   598.0                     Carpet area: 598 (55.56 sq.m.)        2
# 3  3323.0                         Plot area 418(349.5 sq.m.)        5
# 4  1704.0                   Carpet area: 1704 (158.31 sq.m.)        4
#
#    bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1017
# agePossession             0
# super_built_up_area    1701
# built_up_area          1973
# carpet_area            1726
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %% [markdown]
# ### Built up area

# %%
sns.scatterplot(x=df['built_up_area'],y=df['super_built_up_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
sns.scatterplot(x=df['built_up_area'],y=df['carpet_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='carpet_area'>

# %%
((df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull()))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3568    False
# 3569    False
# 3570    False
# 3571    False
# 3572    False
# Length: 3573, dtype: bool

# %%
df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))]
# Out:
#      property_type                   society      sector  price  \
# 11            flat              corona optus  sector 37c   1.22
# 17            flat             tata primanti   sector 72   6.75
# 34            flat  pareena coban residences  sector 99a   1.38
# 37            flat             mahindra aura  sector 110   1.80
# 38            flat                bptp terra  sector 37d   1.40
# ...            ...                       ...         ...    ...
# 3521          flat   professors enclave cghs   sector 56   1.54
# 3536          flat     emaar mgf the enclave   sector 66   1.90
# 3543          flat              corona optus  sector 37c   1.25
# 3553          flat   signature global solera  sector 107   0.50
# 3560          flat   la vida by tata housing  sector 113   1.38
#
#       price_per_sqft    area  \
# 11            6912.0  1765.0
# 17           19286.0  3500.0
# 34            7150.0  1930.0
# 37            8815.0  2042.0
# 38            7731.0  1811.0
# ...

# %%
all_present_df = df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))]

# %%
all_present_df.shape
# Out:
# (530, 24)

# %%
(all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()
# Out:
# np.float64(1.1052289815447711)

# %%
super_to_built_up_ratio = (all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()

# %%
carpet_to_built_up_ratio = (all_present_df['carpet_area']/all_present_df['built_up_area']).median()

# %%
print(super_to_built_up_ratio, carpet_to_built_up_ratio)
# Out:
# 1.1052289815447711 0.9

# %%
# both present, built up null
df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]
# Out:
#      property_type                   society      sector  price  \
# 9             flat      breez global heights  sohna road   0.40
# 10            flat        imperia the esfera  sector 37c   1.40
# 18            flat   signature global synera   sector 81   0.48
# 25            flat   indiabulls centrum park  sector 103   1.33
# 40            flat   signature global solera  sector 107   0.38
# ...            ...                       ...         ...    ...
# 3492          flat                sobha city  sector 108   3.95
# 3519          flat   central park 2 bellevue   sector 48   2.75
# 3528          flat  bestech park view ananda   sector 81   1.10
# 3538          flat           eldeco accolade  sohna road   0.85
# 3550          flat      emaar gurgaon greens  sector 102   1.50
#
#       price_per_sqft    area  \
# 9             6421.0   623.0
# 10            5385.0  2600.0
# 18            8451.0   568.0
# 25            8581.0  1550.0
# 40            6333.0   600.0
# ...

# %%
sbc_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
sbc_df.head()
# Out:
#    property_type                  society      sector  price  price_per_sqft  \
# 9           flat     breez global heights  sohna road   0.40          6421.0
# 10          flat       imperia the esfera  sector 37c   1.40          5385.0
# 18          flat  signature global synera   sector 81   0.48          8451.0
# 25          flat  indiabulls centrum park  sector 103   1.33          8581.0
# 40          flat  signature global solera  sector 107   0.38          6333.0
#
#       area                                       areaWithType  bedRoom  \
# 9    623.0  Super Built up area 623(57.88 sq.m.)Carpet are...        2
# 10  2600.0  Super Built up area 2600(241.55 sq.m.)Carpet a...        4
# 18   568.0  Super Built up area 657(61.04 sq.m.)Carpet are...        2
# 25  1550.0  Super Built up area 1790(166.3 sq.m.)Carpet ar...        3
# 40   600.0  Super Built up area 650(60.39 sq.m.)Carpet are...        2
#
#     bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2))
# Out:
# 9        615.0
# 10      2343.0
# 18       613.0
# 25      1671.0
# 40       627.0
#          ...
# 3492    1900.0
# 3519    2574.0
# 3528    1319.0
# 3538     978.0
# 3550    1315.0
# Name: built_up_area, Length: 421, dtype: float64

# %%
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)

# %%
df.update(sbc_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1017
# agePossession             0
# super_built_up_area    1701
# built_up_area          1552
# carpet_area            1726
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())]
# Out:
#      property_type                  society      sector  price  \
# 0             flat      experion windchants  sector 112   4.75
# 5             flat             tulip violet   sector 69   1.66
# 7             flat  signature global park 4   sector 36   0.72
# 14            flat     whiteland blissville   sector 76   1.90
# 15            flat             nbcc heights   sector 89   1.50
# ...            ...                      ...         ...    ...
# 3558          flat              ss the leaf   sector 85   1.85
# 3561          flat             sahara grace   sector 28   4.30
# 3562          flat               chd avenue   sector 71   1.16
# 3563          flat          the close north   sector 50   2.50
# 3566          flat            sbtl caladium  sector 109   1.60
#
#       price_per_sqft    area                               areaWithType  \
# 0            12623.0  3763.0     Super Built up area 3763(349.59 sq.m.)
# ...

# %%
# sb present c is null built up null
sb_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())]

# %%
sb_df.head()
# Out:
#    property_type                  society      sector  price  price_per_sqft  \
# 0           flat      experion windchants  sector 112   4.75         12623.0
# 5           flat             tulip violet   sector 69   1.66          8409.0
# 7           flat  signature global park 4   sector 36   0.72          6660.0
# 14          flat     whiteland blissville   sector 76   1.90         11364.0
# 15          flat             nbcc heights   sector 89   1.50          7059.0
#
#       area                            areaWithType  bedRoom  bathroom balcony  \
# 0   3763.0  Super Built up area 3763(349.59 sq.m.)        3         5      3+
# 5   1974.0  Super Built up area 1970(183.02 sq.m.)        4         4       1
# 7   1081.0  Super Built up area 1081(100.43 sq.m.)        3         2       3
# 14  1672.0  Super Built up area 1672(155.33 sq.m.)        3         3       2
# 15  2125.0  Super Built up area 2125(197.42 sq.m.)        3         3       3
#
# ...

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105))
# Out:
# 0       3405.0
# 5       1783.0
# 7        978.0
# 14      1513.0
# 15      1923.0
#          ...
# 3558    2179.0
# 3561    3133.0
# 3562    1577.0
# 3563    1894.0
# 3566    2303.0
# Name: built_up_area, Length: 873, dtype: float64

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)

# %%
df.update(sb_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1017
# agePossession             0
# super_built_up_area    1701
# built_up_area           679
# carpet_area            1726
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# sb null c is present built up null
df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]
# Out:
#      property_type                     society      sector  price  \
# 2             flat     signature global synera   sector 81   0.45
# 4             flat                  sare homes   sector 92   0.80
# 12            flat                 green court   sector 90   0.45
# 13            flat               m3m soulitude   sector 89   1.00
# 19            flat     signature global solera  sector 107   0.28
# ...            ...                         ...         ...    ...
# 3549          flat  central park flower valley   sector 33   1.55
# 3554          flat                godrej oasis  sector 88a   1.30
# 3555          flat  huda housing board society   sector 52   0.45
# 3556          flat          godrej nature plus   sector 33   1.90
# 3559          flat                    millenia  sector 37c   0.40
#
#       price_per_sqft    area                      areaWithType  bedRoom  \
# 2             7525.0   598.0    Carpet area: 598 (55.56 sq.m.)        2
# ...

# %%
c_df = df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
c_df.head()
# Out:
#    property_type                  society      sector  price  price_per_sqft  \
# 2           flat  signature global synera   sector 81   0.45          7525.0
# 4           flat               sare homes   sector 92   0.80          4695.0
# 12          flat              green court   sector 90   0.45          7188.0
# 13          flat            m3m soulitude   sector 89   1.00          9066.0
# 19          flat  signature global solera  sector 107   0.28          5622.0
#
#       area                      areaWithType  bedRoom  bathroom balcony  \
# 2    598.0    Carpet area: 598 (55.56 sq.m.)        2         2       2
# 4   1704.0  Carpet area: 1704 (158.31 sq.m.)        4         4       3
# 12   626.0    Carpet area: 626 (58.16 sq.m.)        2         2       1
# 13  1103.0  Carpet area: 1103 (102.47 sq.m.)        2         2       2
# 19   498.0    Carpet area: 489 (45.43 sq.m.)        2         2       2
#
# ...

# %%
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9))
# Out:
# 2        664.0
# 4       1893.0
# 12       696.0
# 13      1226.0
# 19       543.0
#          ...
# 3549    1444.0
# 3554    1990.0
# 3555     513.0
# 3556    2143.0
# 3559     667.0
# Name: built_up_area, Length: 679, dtype: float64

# %%
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)

# %%
df.update(c_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1017
# agePossession             0
# super_built_up_area    1701
# built_up_area             0
# carpet_area            1726
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df[(df['built_up_area'] < 2000) & (df['price'] > 2.5)][['price','area','built_up_area']]
# Out:
#       price    area  built_up_area
# 3      9.85  3323.0          418.0
# 6      9.50  4071.0          500.0
# 31     4.25  1836.0         1836.0
# 36     2.70  1450.0         1450.0
# 49     4.50  1350.0         1350.0
# ...     ...     ...            ...
# 3518  10.50  3618.0          402.0
# 3520   3.50  1449.0         1449.0
# 3525   2.58  1458.0         1444.0
# 3551   3.75  1701.0         1701.0
# 3568   3.69  1557.0         1557.0
#
# [275 rows x 3 columns]

# %%
anamoly_df = df[(df['built_up_area'] < 2000) & (df['price'] > 2.5)][['price','area','built_up_area']]

# %%
anamoly_df.sample(5)
# Out:
#       price    area  built_up_area
# 2698    2.7  2576.0         1891.0
# 2875    3.9  1836.0         1836.0
# 1552   22.0  8250.0         1000.0
# 1989    3.5  1620.0         1620.0
# 2839    2.9  1557.0         1415.0

# %%
anamoly_df['built_up_area'] = anamoly_df['area']

# %%
df.update(anamoly_df)

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat      experion windchants  sector 112   4.75         12623.0
# 1          flat               ild greens  sector 37c   0.90          5614.0
# 2          flat  signature global synera   sector 81   0.45          7525.0
# 3         house              independent   sector 43   9.85         29642.0
# 4          flat               sare homes   sector 92   0.80          4695.0
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         5      3+       4.0        West      Relatively New
# 1        3         3       3       0.0  North-East  Under Construction
# 2        2         2       2       6.0  North-East      Relatively New
# 3        5         5       2       3.0        West        Old Property
# 4        4         4       3       1.0  North-East      Moderately Old
#
#    built_up_area  study room  servant room  store room  pooja room  others  \
# ...

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum             17
# facing             1017
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %% [markdown]
# ### floorNum

# %%
df[df['floorNum'].isnull()]
# Out:
#      property_type                  society             sector  price  \
# 286          house              independent           sector 3   1.50
# 334          house              independent          sector 26   4.60
# 379          house       vipul tatvam villa          sector 48   8.50
# 460          house        ansal sushant lok          sector 43  10.50
# 550          house              independent           sector 2   5.60
# 958          house              independent          sector 25  13.00
# 1181          flat                      NaN          sector 78   0.60
# 1248         house     dlf new town heights          sector 86   2.47
# 1267         house              independent           sector 7   6.50
# 1489         house               jacob pura          sector 12   0.35
# 1534         house       vipul tatvam villa          sector 48   8.50
# 1543         house  ansal sushant lok plots          sector 43   3.30
# ...

# %%
df[df['property_type'] == 'house']['floorNum'].median()
# Out:
# np.float64(2.0)

# %%
df['floorNum'].fillna(2.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum              0
# facing             1017
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %% [markdown]
# ### facing

# %%
df['facing'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.drop(columns=['facing'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                         society      sector  price  \
# 552           flat          experion the heartsong  sector 108   1.70
# 1671          flat               dlf regal gardens   sector 90   1.26
# 1850          flat       signature global rosellia   sector 95   0.45
# 1384          flat                      paras dews  sector 106   1.42
# 3456         house  u block dlf phase 3 road no 21   sector 24   1.60
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 552           8487.0        3         4      3+      14.0  Relatively New
# 1671          7403.0        3         3       3       6.0  Relatively New
# 1850          8755.0        2         2       2      14.0    New Property
# 1384          6030.0        4         6      3+      11.0  Relatively New
# 3456          3292.0        7         5      3+       4.0    Old Property
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# ...

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.drop(index=[2536],inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %% [markdown]
# ### Society

# %%
df[df['society'].isnull()==True]
# Out:
#      property_type society     sector  price  price_per_sqft  bedRoom  \
# 1181          flat     NaN  sector 78    0.6          3692.0        2
#
#       bathroom balcony  floorNum       agePossession  built_up_area  \
# 1181         2       0       2.0  Under Construction         1625.0
#
#       study room  servant room  store room  pooja room  others  \
# 1181           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 1181                1             0

# %%
df.drop(index=[1181],inplace=True)

# %% [markdown]
# ### agePossession - Undefined values imputing

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1612
# New Property           558
# Moderately Old         549
# Old Property           295
# Undefined              293
# Under Construction     264
# Name: count, dtype: int64

# %%
df[df['agePossession'] == 'Undefined']
# Out:
#      property_type                  society      sector  price  \
# 44            flat      trisara our homes 3  sohna road   0.21
# 79            flat       imperia the esfera  sector 37c   0.90
# 97           house              vipul world   sector 48   3.35
# 103           flat          ramsons kshitij   sector 95   0.30
# 122           flat       sare crescent parc   sector 92   0.82
# ...            ...                      ...         ...    ...
# 3535          flat          residency grand   sector 52   5.00
# 3541         house              independent  sector 108   1.34
# 3542          flat       sare crescent parc   sector 92   0.95
# 3570          flat  signature global solera  sector 107   0.60
# 3571          flat            ashiana anmol  sohna road   0.90
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum agePossession  \
# 44            4339.0        1         1       0       2.0     Undefined
# ...

# %%
pd.crosstab(df['property_type'], df['agePossession'])
# Out:
# agePossession  Moderately Old  New Property  Old Property  Relatively New  \
# property_type
# flat                      335           481           123            1434
# house                     214            77           172             178
#
# agePossession  Undefined  Under Construction
# property_type
# flat                 178                 252
# house                115                  12

# %%
pd.crosstab(df['property_type'], df['agePossession'], normalize='index')*100
# Out:
# agePossession  Moderately Old  New Property  Old Property  Relatively New  \
# property_type
# flat                11.951481     17.160186      4.388156       51.159472
# house               27.864583     10.026042     22.395833       23.177083
#
# agePossession  Undefined  Under Construction
# property_type
# flat            6.350339            8.990367
# house          14.973958            1.562500

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='property_type', hue='agePossession')
plt.xticks(rotation=45)
plt.title("Property Type vs Age of Possession")
plt.show()

# %%
from scipy.stats import chi2_contingency

contingency = pd.crosstab(df['property_type'], df['agePossession'])
chi2, p, dof, expected = chi2_contingency(contingency)

print("Chi-Square Statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-Square Statistic: 559.7561322651057
# p-value: 9.99178026171461e-119

# %%
ct = pd.crosstab(df['property_type'], df['agePossession'])
sns.heatmap(ct, annot=True, fmt='d', cmap='Blues')
plt.show()

# %% [markdown]
# If mode_value is empty (no mode found), return NaN, otherwise return the mode

# %%
def mode_based_imputation(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector']) & (df['property_type'] == row['property_type'])]['agePossession'].mode()
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1731
# Moderately Old         592
# New Property           586
# Old Property           328
# Under Construction     278
# Undefined               56
# Name: count, dtype: int64

# %%
def mode_based_imputation2(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation2,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1742
# Moderately Old         598
# New Property           587
# Old Property           331
# Under Construction     280
# Undefined               33
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation3,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1744
# Moderately Old         629
# New Property           587
# Old Property           331
# Under Construction     280
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.to_csv('gurgaon_properties_missing_value_imputation.csv',index=False)

# %%
df.shape
# Out:
# (3571, 18)
