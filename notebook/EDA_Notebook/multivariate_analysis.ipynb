# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r"C:\Users\karth\RealEstatePricePrediction\notebook\cleaned_data\gurgaon_properties_cleaned_v2.csv").drop_duplicates()

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat      experion windchants  sector 112   4.75         12622.0
# 1          flat               ild greens  sector 37c   0.90          5614.0
# 2          flat   breez global hill view  sohna road   0.32          5470.0
# 3          flat  signature global synera   sector 81   0.45          7525.0
# 4         house              independent   sector 43   9.85         29638.0
#
#      area                                       areaWithType  bedRoom  \
# 0  3763.0             Super Built up area 3763(349.59 sq.m.)        3
# 1  1603.0  Super Built up area 1603(148.92 sq.m.)Built Up...        3
# 2   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...        2
# 3   598.0                     Carpet area: 598 (55.56 sq.m.)        2
# 4  3323.0                         Plot area 418(349.5 sq.m.)        5
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         5      3+       4.0        West      Relatively New
# 1         3       3       0.0  North-East  Under Construction
# 2         2       1      17.0         NaN        New Property
# 3         2       2       6.0  North-East      Relatively New
# 4         5       2       3.0        West        Old Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               3763.0            NaN          NaN           0             1
# 1               1603.0         1500.0          NaN           0             0
# 2                  NaN         1000.0        585.0           0             0
# 3                  NaN            NaN        598.0           0             0
# 4                  NaN          418.0          NaN           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            42
# 1           0           0       0                1            66
# 2           0           0       0                1            49
# 3           1           0       0                0            39
# 4           0           1       0                1            21

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 172           flat           ambience caitriona  sector 24  14.00
# 335          house       unitech deerwood chase  sector 50   8.45
# 522          house          huda plot sector 38  sector 38   4.30
# 566          house                  independent  sector 28   4.50
# 609          house                  independent  sector 57   8.00
# 736          house            vatika india next  sector 82   7.00
# 865          house                  independent  sector 38   8.00
# 1001         house                dlf the grove  sector 54   5.70
# 1465         house                  independent  sector 17   3.50
# 1501         house                    rk excelo  sector 12   0.60
# 1780         house                  independent  sector 55   1.45
# 1818         house                  independent  sector 24  10.00
# 1987         house                   ardee city  sector 52   5.50
# 2057         house                        ansal  sector 43   1.85
# 2068         house         eros rosewood villas  sector 49   2.75
# 2073         house                  independent  sector 54   3.75
# 2162         house     unitech uniworld resorts  sector 33   9.50
# 2358         house                  independent  sector 12   6.00
# 2429         house           vipul tatvam villa  sector 48   7.25
# 2482         house       emaar the palm springs  sector 54  24.00
# 3110         house     unitech uniworld resorts  sector 33  10.00
# 3159         house                  independent   sector 4   0.60
# 3251         house         bhim nagar, sector 6   sector 6   0.85
# 3382         house               uppal southend  sector 49   6.75
# 3562         house                  independent  sector 23   2.80
# 3564         house       dlf city plots phase 2  sector 25  10.00
# 3740         house  unitech nirvana birch court  sector 50   7.10
# 3742         house       dlf city plots phase 2  sector 25  10.50
# 3760         house                  independent  sector 12   3.50
#
#       price_per_sqft   area  \
# 172         200000.0  700.0
# 335         235376.0  359.0
# 522         245398.0  175.0
# 566         125000.0  360.0
# 609         266666.0  300.0
# 736         194444.0  360.0
# 865         230547.0  347.0
# 1001        211111.0  270.0
# 1465        218750.0  160.0
# 1501        120000.0   50.0
# 1780        241666.0   60.0
# 1818        229885.0  435.0
# 1987        183333.0  300.0
# 2057        308333.0   60.0
# 2068        178571.0  154.0
# 2073        234375.0  160.0
# 2162        173992.0  546.0
# 2358        315789.0  190.0
# 2429        201388.0  360.0
# 2482        600000.0  400.0
# 3110        181818.0  550.0
# 3159        105263.0   57.0
# 3251        126865.0   67.0
# 3382        290948.0  232.0
# 3562        161849.0  173.0
# 3564        400000.0  250.0
# 3740        283333.0  251.0
# 3742        261194.0  402.0
# 3760        133079.0  263.0
#
#                                            areaWithType  super_built_up_area  \
# 172                    Built Up area: 700 (65.03 sq.m.)                  NaN
# 335                          Plot area 359(33.35 sq.m.)                  NaN
# 522   Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 566                    Built Up area: 360 (33.45 sq.m.)                  NaN
# 609                          Plot area 300(27.87 sq.m.)                  NaN
# 736   Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 865   Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 1001                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 1465                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 1501  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 1780                           Plot area 60(5.57 sq.m.)                  NaN
# 1818                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 1987                         Plot area 300(27.87 sq.m.)                  NaN
# 2057                           Plot area 60(5.57 sq.m.)                  NaN
# 2068  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 2073                         Plot area 160(14.86 sq.m.)                  NaN
# 2162                         Plot area 546(50.73 sq.m.)                  NaN
# 2358  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 2429                         Plot area 360(33.45 sq.m.)                  NaN
# 2482                         Plot area 400(37.16 sq.m.)                  NaN
# 3110                          Plot area 550(51.1 sq.m.)                  NaN
# 3159                            Plot area 57(5.3 sq.m.)                  NaN
# 3251                           Plot area 67(6.22 sq.m.)                  NaN
# 3382                         Plot area 232(21.55 sq.m.)                  NaN
# 3562  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 3564                         Plot area 250(23.23 sq.m.)                  NaN
# 3740                          Plot area 240(22.3 sq.m.)                  NaN
# 3742                         Plot area 402(37.35 sq.m.)                  NaN
# 3760  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
#
#       built_up_area  carpet_area
# 172           700.0          NaN
# 335           359.0          NaN
# 522           145.0          NaN
# 566           360.0          NaN
# 609           300.0          NaN
# 736          3900.0       3743.0
# 865           347.0        215.0
# 1001          270.0          NaN
# 1465          160.0          NaN
# 1501           30.0         15.0
# 1780           60.0          NaN
# 1818            NaN        435.0
# 1987          300.0          NaN
# 2057           60.0          NaN
# 2068            NaN       1650.0
# 2073          160.0          NaN
# 2162          546.0          NaN
# 2358            NaN       1600.0
# 2429          360.0          NaN
# 2482          400.0          NaN
# 3110          550.0          NaN
# 3159           57.0          NaN
# 3251           67.0          NaN
# 3382          232.0          NaN
# 3562          160.0        150.0
# 3564          250.0          NaN
# 3740          240.0          NaN
# 3742          402.0          NaN
# 3760         4800.0       4400.0

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat      experion windchants  sector 112   4.75         12622.0
# 1          flat               ild greens  sector 37c   0.90          5614.0
# 2          flat   breez global hill view  sohna road   0.32          5470.0
# 3          flat  signature global synera   sector 81   0.45          7525.0
# 4         house              independent   sector 43   9.85         29638.0
#
#      area                                       areaWithType  bedRoom  \
# 0  3763.0             Super Built up area 3763(349.59 sq.m.)        3
# 1  1603.0  Super Built up area 1603(148.92 sq.m.)Built Up...        3
# 2   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...        2
# 3   598.0                     Carpet area: 598 (55.56 sq.m.)        2
# 4  3323.0                         Plot area 418(349.5 sq.m.)        5
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         5      3+       4.0        West      Relatively New
# 1         3       3       0.0  North-East  Under Construction
# 2         2       1      17.0         NaN        New Property
# 3         2       2       6.0  North-East      Relatively New
# 4         5       2       3.0        West        Old Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               3763.0            NaN          NaN           0             1
# 1               1603.0         1500.0          NaN           0             0
# 2                  NaN         1000.0        585.0           0             0
# 3                  NaN            NaN        598.0           0             0
# 4                  NaN          418.0          NaN           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            42
# 1           0           0       0                1            66
# 2           0           0       0                1            49
# 3           1           0       0                0            39
# 4           0           1       0                1            21

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                     society     sector  price  \
# 16           house                 independent  sector 46   6.81
# 56           house      dlf city plots phase 3  sector 24   5.00
# 58           house                 independent  sector 13   0.50
# 82           house  unitech palms south city 1  sector 41   9.35
# 111          house                 independent  sector 24   3.20
# ...            ...                         ...        ...    ...
# 3530         house                 independent  sector 55   9.19
# 3564         house      dlf city plots phase 2  sector 25  10.00
# 3684         house                 independent  sector 11   1.35
# 3773         house                 independent  sector 11   4.50
# 3797         house                    shivpuri   sector 7   2.40
#
#       price_per_sqft    area  \
# 16           36911.0  1845.0
# 56           34083.0  1467.0
# 58           90909.0    55.0
# 82           28858.0  3240.0
# 111          59259.0   540.0
# ...              ...     ...
# 3530         34037.0  2700.0
# 3564        400000.0   250.0
# 3684          3857.0  3500.0
# 3773         25000.0  1800.0
# 3797          8889.0  2700.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 16                          Plot area 205(171.41 sq.m.)       12        14
# 56                          Plot area 163(136.29 sq.m.)       13        13
# 58                             Plot area 55(5.11 sq.m.)       12         4
# 82    Plot area 3240(301.01 sq.m.)Built Up area: 750...       10        10
# 111                           Plot area 60(50.17 sq.m.)       14        14
# ...                                                 ...      ...       ...
# 3530                        Plot area 300(250.84 sq.m.)       16        18
# 3564                         Plot area 250(23.23 sq.m.)       12        12
# 3684                       Plot area 3500(325.16 sq.m.)       10         6
# 3773                        Plot area 200(167.23 sq.m.)       16        16
# 3797                        Plot area 300(250.84 sq.m.)       10         5
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 16        3+       NaN        East    New Property                  NaN
# 56        3+       4.0       North    New Property                  NaN
# 58         3       4.0         NaN    Old Property                  NaN
# 82        3+       4.0  North-East  Moderately Old                  NaN
# 111       3+       6.0        West  Relatively New                  NaN
# ...      ...       ...         ...             ...                  ...
# 3530       2       4.0        West    New Property                  NaN
# 3564      3+       4.0       North  Relatively New                  NaN
# 3684      3+       3.0         NaN    Old Property                  NaN
# 3773      3+       4.0       South  Relatively New                  NaN
# 3797       3       2.0       North    Old Property                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 16           1845.0          NaN           0             1           0
# 56           1467.0          NaN           0             0           0
# 58             55.0          NaN           0             0           0
# 82           7500.0       6000.0           1             1           0
# 111           540.0          NaN           0             0           0
# ...             ...          ...         ...           ...         ...
# 3530         2700.0          NaN           0             1           0
# 3564          250.0          NaN           1             1           0
# 3684         3500.0          NaN           0             0           0
# 3773         1800.0          NaN           0             0           0
# 3797         2700.0          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 16             0       1                0            40
# 56             1       0                2            91
# 58             0       0                1            15
# 82             0       0                0            70
# 111            0       0                2            15
# ...          ...     ...              ...           ...
# 3530           1       0                0            49
# 3564           0       0                0           114
# 3684           0       0                1             0
# 3773           0       0                0            20
# 3797           1       0                1             8
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 674          house              independent   sector 92   1.80
# 748          house          godrej meridien  sector 106   5.60
# 871          house  indiabulls centrum park  sector 103   3.25
# 1518         house              greenopolis   sector 89   0.70
# 1567         house         suncity township   sector 54   2.00
# 2051         house      satya the hermitage  sector 103   3.15
# 2400         house              spaze privy   sector 72   3.10
# 2576         house   vatika the seven lamps   sector 82   1.60
# 2910         house           dlf the arbour   sector 63   8.50
# 3127         house      ireo victory valley   sector 67   8.00
# 3135         house        suncity avenue 76   sector 76   0.75
# 3296         house           ats tourmaline  sector 109   1.87
# 3310         house              spaze privy   sector 72   3.09
# 3674         house               ninex city   sector 76   1.75
#
#       price_per_sqft    area  \
# 674           7627.0  2360.0
# 748          14000.0  4000.0
# 871           8125.0  4000.0
# 1518          5397.0  1297.0
# 1567         30968.0   646.0
# 2051          6702.0  4700.0
# 2400          8486.0  3653.0
# 2576          6597.0  2425.0
# 2910         21519.0  3950.0
# 3127         22222.0  3600.0
# 3135         10067.0   745.0
# 3296          8697.0  2150.0
# 3310          6981.0  4426.0
# 3674          6250.0  2800.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 674                  Built Up area: 2360 (219.25 sq.m.)        4         5
# 748                        Plot area 4000(371.61 sq.m.)        5         4
# 871                        Plot area 4000(371.61 sq.m.)        4         3
# 1518                  Built Up area: 1297 (120.5 sq.m.)        2         2
# 1567  Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 2051                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 2400                       Plot area 3653(339.37 sq.m.)        5         5
# 2576                       Plot area 2425(225.29 sq.m.)        4         4
# 2910                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 3127                        Plot area 400(334.45 sq.m.)        6         7
# 3135  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 3296                 Built Up area: 2150 (199.74 sq.m.)        3         4
# 3310  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 3674                   Carpet area: 2800 (260.13 sq.m.)        4         4
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 674        0      13.0         NaN           Undefined                  NaN
# 748       3+      33.0  North-East        New Property                  NaN
# 871       3+      20.0         NaN  Under Construction                  NaN
# 1518       2      14.0  North-East           Undefined                  NaN
# 1567       3      11.0       North      Relatively New                  NaN
# 2051       0      12.0        East           Undefined                  NaN
# 2400      3+      21.0         NaN      Relatively New                  NaN
# 2576      3+      16.0       North      Moderately Old                  NaN
# 2910      3+      27.0         NaN           Undefined                  NaN
# 3127      3+      51.0  North-East      Moderately Old                  NaN
# 3135       2      11.0  North-East        New Property                  NaN
# 3296       0      12.0         NaN           Undefined                  NaN
# 3310      3+      14.0        East      Relatively New                  NaN
# 3674       0      14.0         NaN           Undefined                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 674          2360.0          NaN           0             0           0
# 748          4000.0          NaN           1             1           1
# 871          4000.0          NaN           0             0           0
# 1518         1297.0          NaN           0             0           0
# 1567           60.0         59.0           0             1           0
# 2051         4700.0          NaN           0             0           0
# 2400         3653.0          NaN           0             0           0
# 2576         2425.0          NaN           0             1           0
# 2910         3950.0          NaN           0             0           0
# 3127         3600.0          NaN           1             1           0
# 3135          745.0          NaN           0             0           0
# 3296         2150.0          NaN           0             0           0
# 3310         3653.0       2922.0           0             1           0
# 3674            NaN       2800.0           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 674            0       0                1             0
# 748            1       0                1           151
# 871            0       0                1            51
# 1518           0       0                1             0
# 1567           0       0                2             7
# 2051           0       0                1            61
# 2400           0       0                1             0
# 2576           0       0                1            94
# 2910           0       0                1            61
# 3127           1       0                0            49
# 3135           0       0                1            40
# 3296           0       0                1             0
# 3310           0       0                0            33
# 3674           0       0                1             0

# %%
# conclusion houses(villa) but in appartments

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat      experion windchants  sector 112   4.75         12622.0
# 1          flat               ild greens  sector 37c   0.90          5614.0
# 2          flat   breez global hill view  sohna road   0.32          5470.0
# 3          flat  signature global synera   sector 81   0.45          7525.0
# 4         house              independent   sector 43   9.85         29638.0
#
#      area                                       areaWithType  bedRoom  \
# 0  3763.0             Super Built up area 3763(349.59 sq.m.)        3
# 1  1603.0  Super Built up area 1603(148.92 sq.m.)Built Up...        3
# 2   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...        2
# 3   598.0                     Carpet area: 598 (55.56 sq.m.)        2
# 4  3323.0                         Plot area 418(349.5 sq.m.)        5
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         5      3+       4.0        West      Relatively New
# 1         3       3       0.0  North-East  Under Construction
# 2         2       1      17.0         NaN        New Property
# 3         2       2       6.0  North-East      Relatively New
# 4         5       2       3.0        West        Old Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               3763.0            NaN          NaN           0             1
# 1               1603.0         1500.0          NaN           0             0
# 2                  NaN         1000.0        585.0           0             0
# 3                  NaN            NaN        598.0           0             0
# 4                  NaN          418.0          NaN           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            42
# 1           0           0       0                1            66
# 2           0           0       0                1            49
# 3           1           0       0                0            39
# 4           0           1       0                1            21

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat      experion windchants  sector 112   4.75         12622.0
# 1          flat               ild greens  sector 37c   0.90          5614.0
# 2          flat   breez global hill view  sohna road   0.32          5470.0
# 3          flat  signature global synera   sector 81   0.45          7525.0
# 4         house              independent   sector 43   9.85         29638.0
#
#      area                                       areaWithType  bedRoom  \
# 0  3763.0             Super Built up area 3763(349.59 sq.m.)        3
# 1  1603.0  Super Built up area 1603(148.92 sq.m.)Built Up...        3
# 2   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...        2
# 3   598.0                     Carpet area: 598 (55.56 sq.m.)        2
# 4  3323.0                         Plot area 418(349.5 sq.m.)        5
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         5      3+       4.0        West      Relatively New
# 1         3       3       0.0  North-East  Under Construction
# 2         2       1      17.0         NaN        New Property
# 3         2       2       6.0  North-East      Relatively New
# 4         5       2       3.0        West        Old Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               3763.0            NaN          NaN           0             1
# 1               1603.0         1500.0          NaN           0             0
# 2                  NaN         1000.0        585.0           0             0
# 3                  NaN            NaN        598.0           0             0
# 4                  NaN          418.0          NaN           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            42
# 1           0           0       0                1            66
# 2           0           0       0                1            49
# 3           1           0       0                0            39
# 4           0           1       0                1            21

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat      experion windchants  sector 112   4.75         12622.0
# 1          flat               ild greens  sector 37c   0.90          5614.0
# 2          flat   breez global hill view  sohna road   0.32          5470.0
# 3          flat  signature global synera   sector 81   0.45          7525.0
# 4         house              independent   sector 43   9.85         29638.0
#
#      area                                       areaWithType  bedRoom  \
# 0  3763.0             Super Built up area 3763(349.59 sq.m.)        3
# 1  1603.0  Super Built up area 1603(148.92 sq.m.)Built Up...        3
# 2   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...        2
# 3   598.0                     Carpet area: 598 (55.56 sq.m.)        2
# 4  3323.0                         Plot area 418(349.5 sq.m.)        5
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         5      3+       4.0        West      Relatively New
# 1         3       3       0.0  North-East  Under Construction
# 2         2       1      17.0         NaN        New Property
# 3         2       2       6.0  North-East      Relatively New
# 4         5       2       3.0        West        Old Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               3763.0            NaN          NaN           0             1
# 1               1603.0         1500.0          NaN           0             0
# 2                  NaN         1000.0        585.0           0             0
# 3                  NaN            NaN        598.0           0             0
# 4                  NaN          418.0          NaN           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            42
# 1           0           0       0                1            66
# 2           0           0       0                1            49
# 3           1           0       0                0            39
# 4           0           1       0                1            21

# %% [markdown]
# ### price

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['bedRoom'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['agePossession'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['furnishing_type'].astype('category'))
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(x=df['luxury_score'],y=df['price'])
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ### correlation

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)['price'].sort_values(ascending=False)
# Out:
# price                  1.000000
# super_built_up_area    0.769412
# bathroom               0.589826
# built_up_area          0.551649
# bedRoom                0.522925
# servant room           0.400927
# price_per_sqft         0.391251
# pooja room             0.341492
# store room             0.309121
# study room             0.258602
# luxury_score           0.094775
# area                   0.034720
# others                -0.003525
# carpet_area           -0.011344
# floorNum              -0.094290
# furnishing_type       -0.133418
# Name: price, dtype: float64

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat      experion windchants  sector 112   4.75         12622.0
# 1          flat               ild greens  sector 37c   0.90          5614.0
# 2          flat   breez global hill view  sohna road   0.32          5470.0
# 3          flat  signature global synera   sector 81   0.45          7525.0
# 4         house              independent   sector 43   9.85         29638.0
#
#      area                                       areaWithType  bedRoom  \
# 0  3763.0             Super Built up area 3763(349.59 sq.m.)        3
# 1  1603.0  Super Built up area 1603(148.92 sq.m.)Built Up...        3
# 2   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...        2
# 3   598.0                     Carpet area: 598 (55.56 sq.m.)        2
# 4  3323.0                         Plot area 418(349.5 sq.m.)        5
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         5      3+       4.0        West      Relatively New
# 1         3       3       0.0  North-East  Under Construction
# 2         2       1      17.0         NaN        New Property
# 3         2       2       6.0  North-East      Relatively New
# 4         5       2       3.0        West        Old Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               3763.0            NaN          NaN           0             1
# 1               1603.0         1500.0          NaN           0             0
# 2                  NaN         1000.0        585.0           0             0
# 3                  NaN            NaN        598.0           0             0
# 4                  NaN          418.0          NaN           1             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            42
# 1           0           0       0                1            66
# 2           0           0       0                1            49
# 3           1           0       0                0            39
# 4           0           1       0                1            21

# %%
sns.pairplot(df)
