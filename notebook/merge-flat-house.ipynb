# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                        property_name property_type  \
# 0                   3 BHK Flat in Sector 112 Gurgaon          flat
# 1                   3 BHK Flat in Sector 37C Gurgaon          flat
# 2                                2 BHK Flat in Sohna          flat
# 3                    2 BHK Flat in Sector 81 Gurgaon          flat
# 4  5 Bedroom House for sale in A Block Sushant Lo...         house
#
#                    society  price  price_per_sqft    area  \
# 0      experion windchants   4.75         12622.0  3763.0
# 1               ild greens   0.90          5614.0  1603.0
# 2   breez global hill view   0.32          5470.0   585.0
# 3  signature global synera   0.45          7525.0   598.0
# 4              independent   9.85         29638.0  3323.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0             Super Built up area 3763(349.59 sq.m.)        3         5
# 1  Super Built up area 1603(148.92 sq.m.)Built Up...        3         3
# 2  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...        2         2
# 3                     Carpet area: 598 (55.56 sq.m.)        2         2
# 4                         Plot area 418(349.5 sq.m.)        5         5
#
#   balcony                      additionalRoom  \
# 0      3+                        servant room
# 1       3                       not available
# 2       1                       not available
# 3       2                          store room
# 4       2  pooja room,study room,servant room
#
#                                              address  floorNum      facing  \
# 0               Sector 112 Gurgaon, Gurgaon, Haryana       4.0        West
# 1  Ground Floor, Sector 37C Gurgaon, Gurgaon, Har...       0.0  North-East
# 2               1701 & 1708, Sohna, Gurgaon, Haryana      17.0         NaN
# 3           011, Sector 81 Gurgaon, Gurgaon, Haryana       6.0  North-East
# 4      A Block Sushant Lok Phase 1, Gurgaon, Haryana       3.0        West
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Ansal Plaza', 'Dwaraka Expressway', 'First S...
# 1  Under Construction  ['The Esplanade Mall', 'Gurgaon Road', 'Delhi ...
# 2     0 to 1 Year Old  ['Huda City Centre', 'Omaxe City Centre', 'Nin...
# 3     1 to 5 Year Old  ['Sapphire 83 Mall', 'Delhi Jaipur Expressway'...
# 4        10+ Year Old  ['Mg road metro station', 'Iffco chowk metro s...
#
#                                          description  \
# 0  Experionwindchantsprice\nExperionwindchantsvil...
# 1      Good location with hospital, school close by.
# 2  Both adjacent properties available which can b...
# 3  Signature global is india's no.1 affordable ho...
# 4  Sushant lok a maple community gated line near ...
#
#                                       furnishDetails  \
# 0  ['1 Water Purifier', '5 Geyser', '1 Chimney', ...
# 1                                                NaN
# 2                                                 []
# 3  ['3 Wardrobe', '3 Fan', '1 Exhaust Fan', '2 Ge...
# 4                                                NaN
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Lift(s)', 'Feng Shui / Vaastu Compliant', 'I...
# 2  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 3  ['Power Back-up', 'Security / Fire Alarm', 'Li...
# 4   ['Maintenance Staff', 'Park', 'Visitor Parking']
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction5 out of...
# 1  ['Green Area5 out of 5', 'Amenities4.5 out of ...
# 2  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 3  ['Green Area4 out of 5', 'Construction3 out of...
# 4  ['Environment4 out of 5', 'Safety3 out of 5', ...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
